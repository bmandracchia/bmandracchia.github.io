# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a TSV of publications with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `publications.py`. Run either from the `markdown_generator` folder after replacing `publications.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases of citations, rather than Stuart's non-standard TSV format and citation style.

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: pub_date, title, venue, excerpt, citation, site_url, and paper_url, with a header at the top.
#
# - `excerpt` and `paper_url` can be blank, but the others must have values.
# - `pub_date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper. The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/publications/YYYY-MM-DD-[url_slug]`
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !head citations.csv
# Out:
# Authors,Title,Publication,Volume,Number,Pages,Year,Publisher
# "Pesce, Giuseppe; Mandracchia, B; Orabona, E; Rusciano, Giulia; De Stefano, L; Sasso, Antonio; ",Local electric field measurements by optical tweezers,"Atti della Accademia Peloritana dei Pericolanti-Classe di Scienze Fisiche, Matematiche e Naturali",89,S1,,2011,
# "Pesce, Giuseppe; Mandracchia, Biagio; Orabona, Emanuele; Rusciano, Giulia; De Stefano, Luca; Sasso, Antonio; ",Mapping electric fields generated by microelectrodes using optically trapped charged microspheres,Lab on a Chip,11,23,4113-4116,2011,Royal Society of Chemistry
# "Coppola, Sara; Vespini, Veronica; Merola, Francesco; Mandracchia, Biagio; Grilli, Simonetta; Ferraro, Pietro; ",Unusual 3D lithography approaches for fabrication of polymeric photonic microstructures,Optical Components and Materials XI,8982,,140-151,2014,SPIE
# ...

# %% [markdown]
# ## Import pandas
#
# We are using the very handy pandas library for dataframes.

# %%
import pandas as pd

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
publications = pd.read_csv("Library.csv", sep=",", header=0)
publications
# Out:
#          Key        Item Type  Publication Year  \
# 0   BDT2IM5I   journalArticle              2024
# 1   ETLWRXIV   journalArticle              2024
# 2   PGA6AZ7P         document              2023
# 3   R7SFK43N   journalArticle              2023
# 4   VYKCAI62   journalArticle              2023
# ..       ...              ...               ...
# 72  X28X97GZ   journalArticle              2015
# 73  7AQHIWVR  conferencePaper              2014
# 74  7YES2H77  conferencePaper              2014
# 75  4DMDK2G9   journalArticle              2011
# 76  WPH4JCVN  conferencePaper              2011
#
#                                                Author  \
# 0   Hua, Xuanwen; Han, Keyi; Mandracchia, Biagio; ...
# 1   Mandracchia, Biagio; Zheng, Corey; Rajendran, ...
# 2                       Jia, Shu; Mandracchia, Biagio
# 3   Son, Jeonghwan; Mandracchia, Biagio; Silva Tre...
# 4   Yoon, Kyungduck; Han, Keyi; Tadesse, Kidan; Ma...
# ..                                                ...
# ...

# %%
publications.keys()
# Out:
# Index(['Key', 'Item Type', 'Publication Year', 'Author', 'Title',
#        'Publication Title', 'ISBN', 'ISSN', 'DOI', 'Url', 'Abstract Note',
#        'Date', 'Date Added', 'Date Modified', 'Access Date', 'Pages',
#        'Num Pages', 'Issue', 'Volume', 'Number Of Volumes',
#        'Journal Abbreviation', 'Short Title', 'Series', 'Series Number',
#        'Series Text', 'Series Title', 'Publisher', 'Place', 'Language',
#        'Rights', 'Type', 'Archive', 'Archive Location', 'Library Catalog',
#        'Call Number', 'Extra', 'Notes', 'File Attachments', 'Link Attachments',
#        'Manual Tags', 'Automatic Tags', 'Editor', 'Series Editor',
#        'Translator', 'Contributor', 'Attorney Agent', 'Book Author',
#        'Cast Member', 'Commenter', 'Composer', 'Cosponsor', 'Counsel',
#        'Interviewer', 'Producer', 'Recipient', 'Reviewed Author',
#        'Scriptwriter', 'Words By', 'Guest', 'Number', 'Edition',
# ...

# %%
publications['Author'][1].split(',')[0] + '_' + publications['Publication Title'][1].replace(" ", "_")
# Out:
# 'Mandracchia_Nature_communications'

# %%
publications['Abstract Note'][1]
# Out:
# 'Fluorescence microscopy has undergone rapid advancements, offering unprecedented visualization of biological events and shedding light on the intricate mechanisms governing living organisms. However, the exploration of rapid biological dynamics still poses a significant challenge due to the limitations of current digital camera architectures and the inherent compromise between imaging speed and other capabilities. Here, we introduce sHAPR, a high-speed acquisition technique that leverages the operating principles of sCMOS cameras to capture fast cellular and subcellular processes. sHAPR harnesses custom fiber optics to convert microscopy images into one-dimensional recordings, enabling acquisition at the maximum camera readout rate, typically between 25 and 250 kHz. We have demonstrated the utility of sHAPR with a variety of phantom and dynamic systems, including high-throughput flow cytometry, cardiomyocyte contraction, and neuronal calcium waves, using a standard epi-fluorescence 
# ...

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
import os
for row, item in publications.iterrows():
    
    item.url_slug = item['Author'].split(',')[0] + '_' + str(item['Publication Title']).replace(" ", "_")
    year = item['Publication Year']
    
    md_filename = str(year) + "_" + item.url_slug + ".md"
    html_filename = str(year) + "_" + item.url_slug
    
    
    ## YAML variables
    
    md = "---\ntitle: \""   + item.Title + '"\n'
    
    md += """collection: publications"""
    
    md += """\npermalink: /publication/""" + html_filename
    
    if len(str(item['Abstract Note'])) > 5:
        md += "\nexcerpt: '" + html_escape(item['Abstract Note']) + "'"
    
    md += "\ndate: " + str(year) 
    
    md += "\nvenue: '" + html_escape(str(item['Publication Title'])) + "'"
    
    if len(str(item['Url'])) > 5:
        md += "\npaperurl: '" + item['Url'] + "'"
    
    md += "\nDOI: '" + html_escape(str(item['DOI'])) + "'"
    
    md += "\n---"
    
    ## Markdown description for individual page
        
    if len(str(item['Abstract Note'])) > 5:
        md += "\n" + html_escape(item['Abstract Note']) + "\n"
    
    if len(str(item['Url'])) > 5:
        md += "\n[Download paper here](" + item['Url'] + ")\n" 
        
    # md += "\nRecommended citation: " + item.citation
    
    md_filename = os.path.basename(md_filename)
       
    with open("../_publications/" + md_filename, 'w') as f:
        f.write(md)

# %% [markdown]
# These files are in the publications directory, one directory below where we're working from.

# %%
# !ls ../_publications/
# Out:
#  2011_Pesce_AAPP_Atti_della_Accademia_Peloritana_dei_Pericolanti,_Classe_di_Scienze_Fisiche,_Matematiche_e_Naturali.md
#  2011_Pesce_Lab_on_a_Chip.md
#  2014_Coppola_Micro-Optics_2014.md
#  2014_Coppola_Optical_Components_and_Materials_XI.md
#  2015_Mandracchia_Analytical_Chemistry.md
#  2016_Coppola_IEEE_Journal_on_Selected_Topics_in_Quantum_Electronics.md
#  2016_Mandracchia_Ophthalmic_Technologies_XXVI.md
#  2016_Mandracchia_Quantitative_Phase_Imaging_II.md
#  2017_Bianco_Light:_Science_and_Applications.md
#  2017_Bianco_Optical_Methods_for_Inspection,_Characterization,_and_Imaging_of_Biomaterials_III.md
#  2017_Bianco_Optics_InfoBase_Conference_Papers.md
#  2017_Coppola_Applied_Surface_Science.md
#  2017_Mandracchia_Journal_of_Biophotonics.md
#  2017_Mandracchia_Lab_on_a_Chip.md
#  2017_Mandracchia_nan.md
#  2017_Mandracchia_Optical_Methods_for_Inspection,_Characterization,_and_Imaging_of_Biomaterials_III.md
#  2017_Mandracchia_Optics_InfoBase_Conference_Papers.md
# ...

# %%
# !cat ../_publications/2024_Mandracchia_Nature_communications.md
# Out:
# ---
# title: "High-speed optical imaging with sCMOS pixel reassignment"
# collection: publications
# permalink: /publication/2024_Mandracchia_Nature_communications
# ...
